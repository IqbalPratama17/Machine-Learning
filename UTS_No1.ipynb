# %% [markdown]
# <a href="https://colab.research.google.com/github/IqbalPratama17/Machine-Learning/blob/Python/UTS_No1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Lakukan pemisahan dataset menjadi data training dan data testing dengan komposisi 70% dan 30% serta 80% dan 20%.**

# %%
# Melakukan Pemanggilan file
import pandas as pd
ds = pd.read_csv('/content/drive/My Drive/Machine Learning/dataset/Persentase Perokok RI.csv', engine='python')
ds
# Out:
#                 Provinsi   2015   2016
# 0                   ACEH  29.82  28.16
# 1         SUMATERA UTARA  29.15  27.88
# 2         SUMATERA BARAT  32.41  30.59
# 3                   RIAU  31.21  29.61
# 4                  JAMBI  30.82  29.18
# 5       SUMATERA SELATAN  33.13  31.57
# 6               BENGKULU  33.68  33.15
# 7                LAMPUNG  34.12  33.39
# 8   KEP. BANGKA BELITUNG  30.70  29.32
# 9              KEP. RIAU  29.18  29.25
# 10           DKI JAKARTA  27.31  26.42
# 11            JAWA BARAT  33.82  32.67
# 12           JAWA TENGAH  28.57  27.19
# 13         DI YOGYAKARTA  24.12  23.11
# 14            JAWA TIMUR  29.03  28.16
# 15                BANTEN  32.95  31.64
# 16                  BALI  22.96  21.62
# 17   NUSA TENGGARA BARAT  31.60  30.88
# 18   NUSA TENGGARA TIMUR  25.47  24.91
# 19      KALIMANTAN BARAT  29.35  28.09
# 20     KALIMANTAN TENGAH  30.53  29.21
# 21    KALIMANTAN SELATAN  25.76  25.34
# 22      KALIMANTAN TIMUR  25.59  25.23
# ...

# %%
# Melakukan Pengecekan data teratas
ds.head()
# Out:
#          Provinsi   2015   2016
# 0            ACEH  29.82  28.16
# 1  SUMATERA UTARA  29.15  27.88
# 2  SUMATERA BARAT  32.41  30.59
# 3            RIAU  31.21  29.61
# 4           JAMBI  30.82  29.18

# %%
# Melihat sebaran data
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(ds['2015'],ds['2016'])

# %%
# Membagi data menjadi 2 bagian, data training dan data testing
  # Lakukan penempatan data untuk masing-masing fitur sesuai dengan tipe variablenya
X=ds[['Provinsi','2015']]
y=ds['2016']
X
# Out:
#                 Provinsi   2015
# 0                   ACEH  29.82
# 1         SUMATERA UTARA  29.15
# 2         SUMATERA BARAT  32.41
# 3                   RIAU  31.21
# 4                  JAMBI  30.82
# 5       SUMATERA SELATAN  33.13
# 6               BENGKULU  33.68
# 7                LAMPUNG  34.12
# 8   KEP. BANGKA BELITUNG  30.70
# 9              KEP. RIAU  29.18
# 10           DKI JAKARTA  27.31
# 11            JAWA BARAT  33.82
# 12           JAWA TENGAH  28.57
# 13         DI YOGYAKARTA  24.12
# 14            JAWA TIMUR  29.03
# 15                BANTEN  32.95
# 16                  BALI  22.96
# 17   NUSA TENGGARA BARAT  31.60
# 18   NUSA TENGGARA TIMUR  25.47
# 19      KALIMANTAN BARAT  29.35
# 20     KALIMANTAN TENGAH  30.53
# 21    KALIMANTAN SELATAN  25.76
# 22      KALIMANTAN TIMUR  25.59
# 23      KALIMANTAN UTARA  28.61
# 24        SULAWESI UTARA  29.31
# 25       SULAWESI TENGAH  32.56
# 26      SULAWESI SELATAN  25.49
# 27     SULAWESI TENGGARA  28.49
# ...

# %%
y
# Out:
# 0     28.16
# 1     27.88
# 2     30.59
# 3     29.61
# 4     29.18
# 5     31.57
# 6     33.15
# 7     33.39
# 8     29.32
# 9     29.25
# 10    26.42
# 11    32.67
# 12    27.19
# 13    23.11
# 14    28.16
# 15    31.64
# 16    21.62
# 17    30.88
# 18    24.91
# 19    28.09
# 20    29.21
# 21    25.34
# 22    25.23
# 23    28.38
# 24    29.23
# 25    31.88
# 26    25.13
# 27    27.60
# 28    31.71
# 29    27.36
# 30    25.68
# 31    30.23
# 32    26.18
# 33    24.04
# Name: 2016, dtype: float64

# %%
# Membagi data menjadi 2 bagian, data training dan data testing
from sklearn.model_selection import train_test_split

# %% [markdown]
# **Komposisi 70% dan 30%**

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3)

# %%
# Cek jumlah data untuk X_train dan X_test
len(X_train)
# Out:
# 23

# %%
len(X_test)
# Out:
# 11

# %%
# Melihat isi data dari X_train, X_test dan y_train,y_test
X_train
# Out:
#                 Provinsi   2015
# 5       SUMATERA SELATAN  33.13
# 20     KALIMANTAN TENGAH  30.53
# 27     SULAWESI TENGGARA  28.49
# 3                   RIAU  31.21
# 23      KALIMANTAN UTARA  28.61
# 7                LAMPUNG  34.12
# 30                MALUKU  27.19
# 19      KALIMANTAN BARAT  29.35
# 22      KALIMANTAN TIMUR  25.59
# 13         DI YOGYAKARTA  24.12
# 25       SULAWESI TENGAH  32.56
# 12           JAWA TENGAH  28.57
# 6               BENGKULU  33.68
# 10           DKI JAKARTA  27.31
# 32           PAPUA BARAT  29.28
# 8   KEP. BANGKA BELITUNG  30.70
# 15                BANTEN  32.95
# 26      SULAWESI SELATAN  25.49
# 24        SULAWESI UTARA  29.31
# 4                  JAMBI  30.82
# 31          MALUKU UTARA  31.14
# 16                  BALI  22.96
# 18   NUSA TENGGARA TIMUR  25.47

# %%
X_test
# Out:
#                Provinsi   2015
# 9             KEP. RIAU  29.18
# 0                  ACEH  29.82
# 14           JAWA TIMUR  29.03
# 1        SUMATERA UTARA  29.15
# 11           JAWA BARAT  33.82
# 2        SUMATERA BARAT  32.41
# 21   KALIMANTAN SELATAN  25.76
# 29       SULAWESI BARAT  28.29
# 28            GORONTALO  33.93
# 33                PAPUA  26.67
# 17  NUSA TENGGARA BARAT  31.60

# %% [markdown]
# **Komposisi 80% dan 20%**

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
# Cek jumlah data untuk X_train dan X_test
len(X_train)
# Out:
# 27

# %%
len(X_test)
# Out:
# 7

# %%
# Melihat isi data dari X_train, X_test dan y_train,y_test
X_train
# Out:
#                 Provinsi   2015
# 12           JAWA TENGAH  28.57
# 15                BANTEN  32.95
# 17   NUSA TENGGARA BARAT  31.60
# 32           PAPUA BARAT  29.28
# 19      KALIMANTAN BARAT  29.35
# 3                   RIAU  31.21
# 0                   ACEH  29.82
# 1         SUMATERA UTARA  29.15
# 24        SULAWESI UTARA  29.31
# 4                  JAMBI  30.82
# 33                 PAPUA  26.67
# 28             GORONTALO  33.93
# 27     SULAWESI TENGGARA  28.49
# 5       SUMATERA SELATAN  33.13
# 13         DI YOGYAKARTA  24.12
# 10           DKI JAKARTA  27.31
# 30                MALUKU  27.19
# 26      SULAWESI SELATAN  25.49
# 25       SULAWESI TENGAH  32.56
# 23      KALIMANTAN UTARA  28.61
# 16                  BALI  22.96
# 21    KALIMANTAN SELATAN  25.76
# 11            JAWA BARAT  33.82
# 8   KEP. BANGKA BELITUNG  30.70
# 29        SULAWESI BARAT  28.29
# 22      KALIMANTAN TIMUR  25.59
# 14            JAWA TIMUR  29.03

# %%
X_test
# Out:
#                Provinsi   2015
# 6              BENGKULU  33.68
# 20    KALIMANTAN TENGAH  30.53
# 7               LAMPUNG  34.12
# 2        SUMATERA BARAT  32.41
# 18  NUSA TENGGARA TIMUR  25.47
# 31         MALUKU UTARA  31.14
# 9             KEP. RIAU  29.18
